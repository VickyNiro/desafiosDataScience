# %%
Prueba git2
#TEST CPAP2
#TEST CPAP3
#TEST CPAP4
#TEST CPAP4 gith
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
#   File "<ipython-input-1-1d43e1dfbf44>", line 1
#     Prueba git2
#               ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv("properatti.csv")
df
# Out:
#         Unnamed: 0 operation property_type           place_name  \
# 0                0      sell            PH            Mataderos
# 1                1      sell     apartment             La Plata
# 2                2      sell     apartment            Mataderos
# 3                3      sell            PH              Liniers
# 4                4      sell     apartment               Centro
# 5                5      sell         house         Gualeguaychú
# 6                6      sell            PH                Munro
# 7                7      sell     apartment             Belgrano
# 8                8      sell     apartment             Belgrano
# 9                9      sell         house              Rosario
# 10              10      sell         house              Córdoba
# 11              11      sell         house           San Miguel
# 12              12      sell     apartment             Martínez
# 13              13      sell     apartment         Palermo Soho
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name', 'geonames_id',
#        'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'description', 'title',
#        'image_thumbnail'],
#       dtype='object')

# %% [markdown]
# ## Se identifican aquellas filas con datos faltantes

# %%
#solo 598 filas están completas
df.dropna()
# Out:
#         Unnamed: 0 operation property_type            place_name  \
# 96              96      sell     apartment          San Bernardo
# 691            691      sell            PH              Belgrano
# 692            692      sell            PH              Belgrano
# 693            693      sell            PH              Belgrano
# 694            694      sell            PH               Coghlan
# 695            695      sell            PH               Coghlan
# 746            746      sell     apartment             Caballito
# 781            781      sell     apartment               Coghlan
# 1648          1648      sell     apartment             Balvanera
# 4829          4829      sell     apartment               Palermo
# 4831          4831      sell     apartment            Colegiales
# 5337          5337      sell     apartment          Barrio Norte
# 5362          5362      sell     apartment            El Palomar
# ...

# %% [markdown]
# Columna property_type

# %%
df.loc[df.property_type.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, operation, property_type, place_name, place_with_parent_names, country_name, state_name, geonames_id, lat-lon, lat, lon, price, currency, price_aprox_local_currency, price_aprox_usd, surface_total_in_m2, surface_covered_in_m2, price_usd_per_m2, price_per_m2, floor, rooms, expenses, properati_url, description, title, image_thumbnail]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# Columna place_name

# %%
df.loc[df.place_name.isnull()]
#Todos los de Tigre no tienen el place_name completo. Se usa regex para completarlo.
# Out:
#        Unnamed: 0 operation property_type place_name  \
# 6489         6489      sell         house        NaN
# 10201       10201      sell         house        NaN
# 11451       11451      sell         house        NaN
# 14839       14839      sell         house        NaN
# 18622       18622      sell         house        NaN
# 21922       21922      sell         house        NaN
# 23664       23664      sell         house        NaN
# 24722       24722      sell         house        NaN
# 38856       38856      sell         house        NaN
# 45970       45970      sell     apartment        NaN
# 46642       46642      sell         house        NaN
# 53130       53130      sell         house        NaN
# 55306       55306      sell         house        NaN
# 57703       57703      sell         house        NaN
# 57759       57759      sell         house        NaN
# 57764       57764      sell         house        NaN
# 57793       57793      sell         house        NaN
# ...

# %%
df.place_name.fillna('Tigre', inplace = True)

# %%
df.loc[df.place_name.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, operation, property_type, place_name, place_with_parent_names, country_name, state_name, geonames_id, lat-lon, lat, lon, price, currency, price_aprox_local_currency, price_aprox_usd, surface_total_in_m2, surface_covered_in_m2, price_usd_per_m2, price_per_m2, floor, rooms, expenses, properati_url, description, title, image_thumbnail]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# Columna place_with_parent_names

# %%
df.loc[df.place_with_parent_names.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, operation, property_type, place_name, place_with_parent_names, country_name, state_name, geonames_id, lat-lon, lat, lon, price, currency, price_aprox_local_currency, price_aprox_usd, surface_total_in_m2, surface_covered_in_m2, price_usd_per_m2, price_per_m2, floor, rooms, expenses, properati_url, description, title, image_thumbnail]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# Columna country_name

# %%
df.loc[df.country_name.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, operation, property_type, place_name, place_with_parent_names, country_name, state_name, geonames_id, lat-lon, lat, lon, price, currency, price_aprox_local_currency, price_aprox_usd, surface_total_in_m2, surface_covered_in_m2, price_usd_per_m2, price_per_m2, floor, rooms, expenses, properati_url, description, title, image_thumbnail]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# Columna state_name

# %%
df.loc[df.state_name.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, operation, property_type, place_name, place_with_parent_names, country_name, state_name, geonames_id, lat-lon, lat, lon, price, currency, price_aprox_local_currency, price_aprox_usd, surface_total_in_m2, surface_covered_in_m2, price_usd_per_m2, price_per_m2, floor, rooms, expenses, properati_url, description, title, image_thumbnail]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# Columna geonames_id

# %%
df.loc[df.geonames_id.isnull()]
#geonames_id corresponde al id de cada 'place_name'.
# Out:
#         Unnamed: 0 operation property_type  \
# 11              11      sell         house
# 17              17      sell     apartment
# 23              23      sell     apartment
# 26              26      sell         house
# 27              27      sell         house
# 33              33      sell     apartment
# 36              36      sell         house
# 38              38      sell     apartment
# 44              44      sell         house
# 45              45      sell     apartment
# 46              46      sell            PH
# 61              61      sell         house
# 63              63      sell         house
# 65              65      sell         store
# 104            104      sell         house
# 109            109      sell     apartment
# 127            127      sell         house
# 182            182      sell         house
# 202            202      sell         house
# 209            209      sell     apartment
# 234            234      sell         house
# ...

# %%
#Con sort_values se identifico que el registro nro 7367
#tenia mal cargado el place_name
df.iloc[7367 , 3] = 'Tigre'
df
# Out:
#         Unnamed: 0 operation property_type           place_name  \
# 0                0      sell            PH            Mataderos
# 1                1      sell     apartment             La Plata
# 2                2      sell     apartment            Mataderos
# 3                3      sell            PH              Liniers
# 4                4      sell     apartment               Centro
# 5                5      sell         house         Gualeguaychú
# 6                6      sell            PH                Munro
# 7                7      sell     apartment             Belgrano
# 8                8      sell     apartment             Belgrano
# 9                9      sell         house              Rosario
# 10              10      sell         house              Córdoba
# 11              11      sell         house           San Miguel
# 12              12      sell     apartment             Martínez
# 13              13      sell     apartment         Palermo Soho
# ...

# %%
df = df.sort_values('place_name')
df
#Encontramos que hay place_name sin geonames_id. Ej:los alamos
# Out:
#         Unnamed: 0 operation property_type               place_name  \
# 33586        33586      sell         house   Country Maschwitz Club
# 45159        45159      sell         house   Country Maschwitz Club
# 42404        42404      sell         house   Country Maschwitz Club
# 23730        23730      sell     apartment               los alamos
# 25553        25553      sell         house               9 de Abril
# 78527        78527      sell         store               9 de Abril
# 84843        84843      sell         store               9 de Abril
# 110487      110487      sell         house                   Abasto
# 40488        40488      sell         house                   Abasto
# 40487        40487      sell         house                   Abasto
# 40486        40486      sell         house                   Abasto
# 83827        83827      sell         house                   Abasto
# 20373        20373      sell     apartment                   Abasto
# ...

# %% [markdown]
# Columna lat-lon

# %%
df.loc[df['lat-lon'].isnull()]
# Out:
#         Unnamed: 0 operation property_type   place_name  \
# 78527        78527      sell         store   9 de Abril
# 84843        84843      sell         store   9 de Abril
# 110487      110487      sell         house       Abasto
# 40488        40488      sell         house       Abasto
# 83827        83827      sell         house       Abasto
# 56063        56063      sell         house       Abasto
# 56064        56064      sell         house       Abasto
# 56065        56065      sell         house       Abasto
# 56066        56066      sell         house       Abasto
# 56062        56062      sell         house       Abasto
# 92381        92381      sell     apartment       Abasto
# 79687        79687      sell         house       Abasto
# 40955        40955      sell     apartment       Abasto
# 40953        40953      sell     apartment       Abasto
# 92574        92574      sell     apartment       Abasto
# 40842        40842      sell         house       Abasto
# ...

# %% [markdown]
# Columna lat

# %%
df.loc[df['lat'].isnull()]
# Out:
#         Unnamed: 0 operation property_type   place_name  \
# 78527        78527      sell         store   9 de Abril
# 84843        84843      sell         store   9 de Abril
# 110487      110487      sell         house       Abasto
# 40488        40488      sell         house       Abasto
# 83827        83827      sell         house       Abasto
# 56063        56063      sell         house       Abasto
# 56064        56064      sell         house       Abasto
# 56065        56065      sell         house       Abasto
# 56066        56066      sell         house       Abasto
# 56062        56062      sell         house       Abasto
# 92381        92381      sell     apartment       Abasto
# 79687        79687      sell         house       Abasto
# 40955        40955      sell     apartment       Abasto
# 40953        40953      sell     apartment       Abasto
# 92574        92574      sell     apartment       Abasto
# 40842        40842      sell         house       Abasto
# ...

# %%
df.loc[df['surface_total_in_m2'].isnull()]
# Out:
#         Unnamed: 0 operation property_type               place_name  \
# 45159        45159      sell         house   Country Maschwitz Club
# 78527        78527      sell         store               9 de Abril
# 110487      110487      sell         house                   Abasto
# 40488        40488      sell         house                   Abasto
# 40487        40487      sell         house                   Abasto
# 40486        40486      sell         house                   Abasto
# 83827        83827      sell         house                   Abasto
# 40489        40489      sell         house                   Abasto
# 21436        21436      sell         house                   Abasto
# 71990        71990      sell     apartment                   Abasto
# 79687        79687      sell         house                   Abasto
# 52901        52901      sell     apartment                   Abasto
# 40842        40842      sell         house                   Abasto
# ...

# %%
df.floor.value_counts()
# Out:
# 1.0       2080
# 2.0       1542
# 3.0        914
# 4.0        658
# 5.0        484
# 6.0        483
# 7.0        355
# 8.0        248
# 9.0        205
# 10.0       181
# 11.0       123
# 12.0       116
# 13.0        69
# 14.0        49
# 15.0        41
# 17.0        31
# 16.0        24
# 22.0        16
# 18.0        15
# 19.0        10
# 27.0         6
# 25.0         6
# 20.0         6
# 21.0         6
# 108.0        5
# 33.0         5
# 31.0         4
# 1609.0       4
# 403.0        4
# 104.0        4
#           ...
# 1206.0       1
# 410.0        1
# 803.0        1
# 1202.0       1
# 910.0        1
# 338.0        1
# 89.0         1
# 48.0         1
# 118.0        1
# 56.0         1
# 404.0        1
# 26.0         1
# 34.0         1
# 201.0        1
# 1106.0       1
# 810.0        1
# 1109.0       1
# 406.0        1
# 213.0        1
# 433.0        1
# 110.0        1
# 343.0        1
# 252.0        1
# 43.0         1
# 303.0        1
# 60.0         1
# 1379.0       1
# ...

# %%
#Solo hay ventas. Vble no significativa.
df.operation.value_counts()

# %%
#Tipo de propiedad
df.property_type.value_counts()

# %%
df.place_name.value_counts()

# %%
#solo hay propiedades de Argentina. Variable no significativa.
df.country_name.value_counts()

# %%
df.state_name.value_counts()
